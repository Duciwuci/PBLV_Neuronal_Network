# %%
#imports
import testdata.TestDataGenerator as tdg
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import random
import numpy

# %%
#definitions

DIMENSIONS=2
SENSORS= 4

COORDINATE_SYSTEM = 1

INPUT_NODES = SENSORS
HIDDEN_NODES = [64,64]
OUTPUT_NODES = DIMENSIONS

# %%
#Generate train data

distances, datapoints, sensors = tdg.generateStatic4PointIO(100,2,COORDINATE_SYSTEM)

# %%
#Generate Model
inp = keras.layers.Input((SENSORS,))

x = keras.layers.Dense(32, activation='relu')(inp)
x = keras.layers.Dense(32, activation='relu')(x)
xOut = keras.layers.Dense(1, activation='relu', name='xOut')(x)
yOut = keras.layers.Dense(1, activation='relu', name='yOut')(x)
model = keras.models.Model(inputs=inp, outputs=[xOut, yOut])

model.compile(optimizer='adam', loss='mean_squared_error', metrics=['accuracy'])

# %%
hist = model.fit(distances,datapoints,epochs =25)
plt.title('loss function')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.plot(hist.history['loss'])
plt.plot(hist.history['yOut_loss'])
plt.plot(hist.history['xOut_loss'])
plt.legend(['loss', 'y-Loss', 'x-Loss'], loc='upper left')
# Out:
# Epoch 1/25
# 100/100 [==============================] - 2s 15ms/step - loss: 0.5879 - xOut_loss: 0.2414 - yOut_loss: 0.3465 - xOut_acc: 0.0000e+00 - yOut_acc: 0.0000e+00
# Epoch 2/25
# 100/100 [==============================] - 0s 148us/step - loss: 0.4800 - xOut_loss: 0.1329 - yOut_loss: 0.3470 - xOut_acc: 0.0000e+00 - yOut_acc: 0.0000e+00
# Epoch 3/25
# 100/100 [==============================] - 0s 119us/step - loss: 0.4209 - xOut_loss: 0.0727 - yOut_loss: 0.3482 - xOut_acc: 0.0000e+00 - yOut_acc: 0.0000e+00
# Epoch 4/25
# 100/100 [==============================] - 0s 168us/step - loss: 0.4115 - xOut_loss: 0.0631 - yOut_loss: 0.3484 - xOut_acc: 0.0000e+00 - yOut_acc: 0.0000e+00
# Epoch 5/25
# 100/100 [==============================] - 0s 124us/step - loss: 0.4125 - xOut_loss: 0.0660 - yOut_loss: 0.3465 - xOut_acc: 0.0000e+00 - yOut_acc: 0.0000e+00
# Epoch 6/25
# 100/100 [==============================] - 0s 145us/step - loss: 0.4019 - xOut_loss: 0.0600 - yOut_loss: 0.3420 - xOut_acc: 0.0000e+00 - yOut_acc: 0.0000e+00
# Epoch 7/25
# 100/100 [==============================] - 0s 115us/step - loss: 0.3841 - xOut_loss: 0.0498 - yOut_loss: 0.3344 - xOut_acc: 0.0000e+00 - yOut_acc: 0.0000e+00
# Epoch 8/25
# 100/100 [==============================] - 0s 144us/step - loss: 0.3656 - xOut_loss: 0.0445 - yOut_loss: 0.3212 - xOut_acc: 0.0000e+00 - yOut_acc: 0.0000e+00
# Epoch 9/25
# 100/100 [==============================] - 0s 144us/step - loss: 0.3375 - xOut_loss: 0.0438 - yOut_loss: 0.2937 - xOut_acc: 0.0000e+00 - yOut_acc: 0.0000e+00
# Epoch 10/25
# 100/100 [==============================] - 0s 126us/step - loss: 0.2866 - xOut_loss: 0.0432 - yOut_loss: 0.2434 - xOut_acc: 0.0000e+00 - yOut_acc: 0.0000e+00
# Epoch 11/25
# 100/100 [==============================] - 0s 119us/step - loss: 0.2534 - xOut_loss: 0.0397 - yOut_loss: 0.2136 - xOut_acc: 0.0000e+00 - yOut_acc: 0.0000e+00
# Epoch 12/25
# 100/100 [==============================] - 0s 143us/step - loss: 0.2325 - xOut_loss: 0.0347 - yOut_loss: 0.1977 - xOut_acc: 0.0000e+00 - yOut_acc: 0.0000e+00
# Epoch 13/25
# 100/100 [==============================] - 0s 157us/step - loss: 0.2147 - xOut_loss: 0.0329 - yOut_loss: 0.1819 - xOut_acc: 0.0000e+00 - yOut_acc: 0.0000e+00
# Epoch 14/25
# 100/100 [==============================] - 0s 144us/step - loss: 0.1954 - xOut_loss: 0.0308 - yOut_loss: 0.1646 - xOut_acc: 0.0000e+00 - yOut_acc: 0.0000e+00
# Epoch 15/25
# 100/100 [==============================] - 0s 136us/step - loss: 0.1796 - xOut_loss: 0.0284 - yOut_loss: 0.1512 - xOut_acc: 0.0000e+00 - yOut_acc: 0.0000e+00
# Epoch 16/25
# 100/100 [==============================] - 0s 139us/step - loss: 0.1657 - xOut_loss: 0.0268 - yOut_loss: 0.1389 - xOut_acc: 0.0000e+00 - yOut_acc: 0.0000e+00
# Epoch 17/25
# 100/100 [==============================] - 0s 156us/step - loss: 0.1539 - xOut_loss: 0.0253 - yOut_loss: 0.1286 - xOut_acc: 0.0000e+00 - yOut_acc: 0.0000e+00
# Epoch 18/25
# 100/100 [==============================] - 0s 157us/step - loss: 0.1419 - xOut_loss: 0.0233 - yOut_loss: 0.1185 - xOut_acc: 0.0000e+00 - yOut_acc: 0.0000e+00
# Epoch 19/25
# 100/100 [==============================] - 0s 158us/step - loss: 0.1306 - xOut_loss: 0.0210 - yOut_loss: 0.1096 - xOut_acc: 0.0000e+00 - yOut_acc: 0.0000e+00
# Epoch 20/25
# 100/100 [==============================] - 0s 175us/step - loss: 0.1232 - xOut_loss: 0.0201 - yOut_loss: 0.1031 - xOut_acc: 0.0000e+00 - yOut_acc: 0.0000e+00
# Epoch 21/25
# 100/100 [==============================] - 0s 211us/step - loss: 0.1140 - xOut_loss: 0.0184 - yOut_loss: 0.0955 - xOut_acc: 0.0000e+00 - yOut_acc: 0.0000e+00
# Epoch 22/25
# 100/100 [==============================] - 0s 188us/step - loss: 0.1036 - xOut_loss: 0.0162 - yOut_loss: 0.0874 - xOut_acc: 0.0000e+00 - yOut_acc: 0.0000e+00
# Epoch 23/25
# 100/100 [==============================] - 0s 119us/step - loss: 0.0927 - xOut_loss: 0.0145 - yOut_loss: 0.0782 - xOut_acc: 0.0000e+00 - yOut_acc: 0.0000e+00
# Epoch 24/25
# 100/100 [==============================] - 0s 148us/step - loss: 0.0796 - xOut_loss: 0.0129 - yOut_loss: 0.0668 - xOut_acc: 0.0000e+00 - yOut_acc: 0.0000e+00
# Epoch 25/25
# 100/100 [==============================] - 0s 153us/step - loss: 0.0693 - xOut_loss: 0.0118 - yOut_loss: 0.0575 - xOut_acc: 0.0000e+00 - yOut_acc: 0.0000e+00

# %%
result = model.predict(distances)

plt.ylabel('value')
plt.xlabel('dataset')
plt.title('y-prediction')
plt.plot(datapoints[1])   
plt.plot(result[1])
plt.legend(['testdata', 'neuronal prediction'])

# %%
plt.title('x-prediction')
plt.ylabel('value')
plt.xlabel('dataset')
plt.plot(datapoints[0])   
plt.plot(result[0])
plt.legend(['testdata', 'neuronal prediction'])

# %%
test_distance, test_datapoint, test_sensor = tdg.generateStatic4PointIO(100,2,COORDINATE_SYSTEM)   

testResult = model.predict(test_distance)

plt.ylabel('value')
plt.xlabel('dataset')
plt.title('y-prediction with new generated data')
plt.plot(test_datapoint[1])   
plt.plot(testResult[1])
plt.legend(['testdata', 'neuronal prediction'])

# %%
plt.title('x-prediction with new generated data')
plt.ylabel('value')
plt.xlabel('dataset')
plt.plot(test_datapoint[0])   
plt.plot(testResult[0])
plt.legend(['testdata', 'neuronal prediction'])

# %%
evaluation = model.evaluate(distances,test_datapoint)
 
print(evaluation[0])
# Out:
# 100/100 [==============================] - 1s 7ms/step
# 0.20744403719902038

# %%
plt.plot(test_datapoint[0], test_datapoint[1], 'bo')
plt.plot(testResult[0], testResult[1], 'ro')
plt.legend(['testdata', 'prediction'])

# %%
plt.title('x-prediction with new generated data')
plt.ylabel('prediction')
plt.xlabel('value')
plt.plot([0,1])
plt.plot(test_datapoint[0], testResult[0], 'ro')

# %%
plt.title('y-prediction with new generated data')
plt.ylabel('prediction')
plt.xlabel('value')
plt.plot([0,1])
plt.plot(test_datapoint[1], testResult[1], 'ro')
